# %% [markdown]
# # Stock

# %% [markdown]
# ## Load data

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## pandas_datareader

# %%
#!pip install pandas_datareader

# %%
from pandas_datareader import data
from datetime import datetime

# %% [markdown]
# ### Tesla

# %%
tsla = data.DataReader('TSLA', 'yahoo', datetime(2017,1,1), datetime(2017,12,31))
tsla

# %% [markdown]
# ### KOSPI 200

# %%
#ks200 = data.DataReader('KOSPI200.KS', 'yahoo', datetime(2019,1,1), datetime(2020,10,13))
#ks200

# %% [markdown]
# ## Finance Data Reader

# %% [markdown]
# [FinanceDataReader 사용자 안내서](https://nbviewer.jupyter.org/gist/FinanceData/8fb5806466f9bd8e923d447387fc8dc9)

# %%
#!pip install finance_datareader

# %%
import FinanceDataReader as fdr
fdr.__version__

# %% [markdown]
# ### 한국거래소 상장종목 전체 리스트

# %%
df_krx = fdr.StockListing('KRX')
df_krx.head()

# %% [markdown]
# ### S&P 500 종목 전체 리스트

# %%
df_spx = fdr.StockListing('S&P500')
df_spx.head()

# %% [markdown]
# ### KS11 (KOSPI 지수)

# %%
df = fdr.DataReader('KS11', '2020')
df

# %%
df['Close'].plot()

# %% [markdown]
# ### KOSDAQ 지수

# %%
fdr.DataReader('KQ11', '2020')

# %% [markdown]
# ### 코스피 200 지수

# %%
fdr.DataReader('KS200', '2020')

# %%
df = fdr.DataReader('KS200', '2020-01-01', '2020-12-31')
df

# %%
df[['Open','Close']].plot()
plt.show()

# %% [markdown]
# ### 다우존스 지수

# %%
fdr.DataReader('DJI', '2020')

# %% [markdown]
# ### 나스닥 지수

# %%
fdr.DataReader('IXIC', '2020')

# %% [markdown]
# ---

# %%
# End of file
